# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
run ducks25.ipynb
# Out:
# ducks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/path/Goalie/ducks.ipynb in <module>
#      18 df = pd.read_html(str(table))[0]
#      19 selected_columns = ['Date','Unnamed: 6', 'GF', 'GA']
# ---> 20 df_ducks251 = df[selected_columns]
#      21 df_ducks251['GD'] = df_ducks251['GF'] - df['GA']
#      22 selected_columns2 = ['Date', 'Unnamed: 6','GD']
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# ...

# %%
run flames25.ipynb
# Out:
# flames.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# flames.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# flames.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run canucks25.ipynb
# Out:
# canucks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# canucks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# canucks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run kings25.ipynb
# Out:
# kings.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# kings.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# kings.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run oilers25.ipynb
# Out:
# oilers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# oilers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# oilers.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run sharks25.ipynb
# Out:
# sharks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# sharks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# sharks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run kraken25.ipynb
# Out:
# kraken.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# kraken.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# kraken.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run canucks.ipynb
# Out:
# canucks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# canucks.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# canucks.ipynb:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   {
# ...

# %%
run vegas25.ipynb
# Out:
# vegas.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# vegas.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# vegas.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run blackhawks25.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/path/Goalie/blackhawks.ipynb in <module>
#       2
#       3 # Send a request to fetch the HTML content of the page
# ----> 4 response = requests.get(url)
#       5 html_content = response.text
#       6
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
run avalanche25.ipynb
# Out:
# avalanche.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# avalanche.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# avalanche.ipynb:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "text": [
# ...

# %%
run stars25.ipynb
# Out:
# stars.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# stars.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# stars.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run wild25.ipynb
# Out:
# wild.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# wild.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# wild.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run predators25.ipynb
# Out:
# predators.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# predators.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# predators.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run blues25.ipynb
# Out:
# blues.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# blues.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# blues.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run utah25.ipynb
# Out:
# utah.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ]
# utah.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ]
# utah.ipynb:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "execution_count": 2,
# ...

# %%
run winnipeg25.ipynb
# Out:
# winnipeg.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# winnipeg.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# winnipeg.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run hurricanes25.ipynb
# Out:
# hurricanes.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# hurricanes.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# hurricanes.ipynb:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "text": [
# ...

# %%
run jackets25.ipynb
# Out:
# jackets.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# jackets.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# jackets.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run devils25.ipynb
# Out:
# devils.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# devils.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# devils.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run islanders25.ipynb
# Out:
# islanders.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# islanders.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# islanders.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run rangers25.ipynb
# Out:
# rangers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# rangers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# rangers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run flyers25.ipynb
# Out:
# flyers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# flyers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# flyers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run penguins25.ipynb
# Out:
# penguins.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# penguins.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# penguins.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run washington25.ipynb
# Out:
# washington.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# washington.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# washington.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
run bruins25.ipynb
# Out:
# bruins.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# bruins.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# bruins.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run sabres25.ipynb
# Out:
# sabres.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# sabres.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# sabres.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run wings25.ipynb
# Out:
# wings.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# wings.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# wings.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run panthers25.ipynb
# Out:
# panthers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# panthers.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# panthers.ipynb:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "metadata": {},
# ...

# %%
run canadiens25.ipynb
# Out:
# canadiens.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# canadiens.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# canadiens.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run senators25.ipynb
# Out:
# senators.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# senators.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# senators.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run lightning2025.ipynb
# Out:
# lightning.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# lightning.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# lightning.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
run leafs25.ipynb
# Out:
# leafs.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# leafs.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# leafs.ipynb:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   "outputs": [
# ...

# %%
df_combined = pd.concat([df_johngibson, df_lukasdostal,df_mattvillalta,df_karelvejmelka,df_connoringram,df_jeremyswayman,
                        df_linusullmark,df_ericcomrie,df_devonlevi,df_ukkopekkaluukkonen,df_anttiraanta,df_jetgreaves,
                        df_spencermartin,df_pyotrkochetkov,df_frederikandersen,df_yanivperets,df_elvismerzlikins,
                        df_daniiltarasov, df_malcolmsubban,df_dustinwolf,df_danvladar,df_jacobmarkstrom,
                        df_ivanprosvetov,df_alexandargeorgiev,df_justusannunen,df_arvidsoderblom,df_petrmrazek,
                        df_scottwedgewood,df_jakeoettinger,df_mattmurray,df_spencermartin2,df_alexlyon,
                        df_michaelhutchinson,df_villehusso,df_jamesreimer,df_stuartskinner,df_jackcampbell,
                        df_calvinpickard,df_anthonystolarz,df_sergeibobrovsky,df_pheonixcopley,df_camtalbot,
                        df_davidrittich,df_filipgustavsson,df_jesperwallstedt,df_marcandrefleury,
                        df_jakeallen,df_sammontembeault,df_caydenprimeau,df_jakeallen2,df_vitekvanecek,
                        df_akiraschmid,df_kaapokahkonen,df_nicodaws,df_juusesaros,df_kevinlankinen,
                        df_yaroslavaskarov,df_kennethappleby,df_ilyasorokin,df_semyonvarlamov,
                        df_jonathanquick,df_igorshesterkin,df_louisdomingue,df_madssogaard,df_joonaskorpisalo,
                        df_antonforsberg,df_carterhart,df_samuelersson,df_felixsandstrom,df_calpetersen,
                        df_ivanfedotov,df_alexnedeljkovic,df_magnushellberg,df_tristanjarry,df_devincooley,
                        df_magnuschrona,df_kaapokahkonen2,df_mackenzieblackwood,df_georgiromanov,
                        df_philippgrubauer,df_chrisdriedger,df_joeydaccord,df_jordanbinnington,
                        df_joelhofer,df_matttomkins,df_andreivasilevskiy,df_jonasjohansson,df_martinjones,
                        df_josephwoll,df_ilyasamsonov,df_thatcherdemko,df_arturssilovs,df_caseydesmith,
                        df_adinhill,df_jiripatera,df_loganthompson,df_connorhellebuyck,
                        df_laurentbrossoit,df_darcykuemper,df_huntershepard,df_charlielindgren], axis=0)

df_impact_totals = df_combined.groupby(['Goalie', 'Team','Impact']).size().unstack(fill_value=0)
df_impact_totals['Year'] = '2023-24'
columns_to_sum = ['Bad in Win', 'Goalie Loss', 'Goalie Win', 'No Impact', 'Strong in Loss']  # Replace with your column names
df_impact_totals['Games'] = df_impact_totals[columns_to_sum].sum(axis=1)
df_impact_totals = df_impact_totals[['Year','Games','Goalie Win','Goalie Loss','Strong in Loss','Bad in Win','No Impact']]

# Display the result

# %%
df_combined23 = pd.concat([df_lukasdostal23,df_johngibson23,df_olleerikssonek23,df_anthonystolarz23,
                          df_ivanprosvetov23,df_connoringram23,df_karelvejmelka23,df_jeremyswayman23,
                          df_linusullmark23,df_keithkinkaid23,df_devonlevi23,df_ukkopekkaluukkonen23,
                          df_ericcomrie23,df_craiganderson23,df_frederikandersen23,df_anttiraanta23,
                          df_pyotrkochetkov23,df_elvismerzlikins23,df_jongillies23,df_michaelhutchinson23,
                          df_jetgreaves23,df_daniiltarasov23,df_joonaskorpisalo23,df_dustinwolf23,
                          df_jacobmarkstrom23,df_danvladar23,df_jaxsonstauber23,df_petrmrazek23,
                          df_antonkhudobin23,df_arvidsoderblom23,df_dylanwells23,df_alexstalock23,
                          df_alexandargeorgiev23,df_keithkinkaid232,df_justusannunen23,df_jonasjohansson23,
                          df_pavelfrancouz23,df_jakeoettinger23,df_mattmurray23,df_scottwedgewood23,
                          df_magnushellberg23,df_villehusso23,df_alexnedeljkovic23,df_stuartskinner23,
                          df_jackcampbell23,df_matthewberlin23,df_alexlyon23,df_spencerknight23,
                          df_sergeibobrovsky23,df_jonathanquick23,df_calpetersen23,df_pheonixcopley23,
                          df_joonaskorpisalo232,df_marcandrefleury23,df_filipgustavsson23,df_jakeallen23,
                          df_caydenprimeau23,df_sammontembeault23,df_mackenzieblackwood23,df_akiraschmid23,
                          df_vitekvanecek23,df_juusesaros23,df_kevinlankinen23,df_yaroslavaskarov23,
                          df_igorshesterkin23,df_jaroslavhalak23,df_semyonvarlamov23,df_ilyasorokin23,
                          df_antonforsberg23,df_magnushellberg232,df_camtalbot23,df_leevimerilainen23,
                          df_madssogaard23,df_kevinmadolese23,df_dylanferguson23,df_carterhart23,
                          df_samuelersson23,df_felixsandstrom23,df_caseydesmith23,df_dustintokarski23,
                          df_tristanjarry23,df_eetumakiniemi23,df_aarondell23,df_jamesreimer23,
                          df_kaapokahkonen23,df_martinjones23,df_joeydaccord23,df_philippgrubauer23,
                          df_jordanbinnington23,df_thomasgreiss23,df_joelhofer23,df_brianelliott23,
                          df_andreivasilevskiy23,df_mattmurray232,df_josephwoll23,df_erikkallgren23,
                          df_ilyasamsonov23,df_jettalexander23,df_arturssilovs23,df_spencermartin23,
                          df_thatcherdemko23,df_collindelia23,df_loganthompson23,df_adinhill23,
                          df_jonathanquick232,df_jiripatera23,df_laurentbrossoit23,df_davidrittich23,
                          df_connorhellebuyck23,df_charlielindgren23,df_darcykuemper23], axis=0)

df_impact_totals23 = df_combined23.groupby(['Goalie', 'Team','Impact']).size().unstack(fill_value=0)
df_impact_totals23['Year'] = '2022-23'
columns_to_sum = ['Bad in Win', 'Goalie Loss', 'Goalie Win', 'No Impact', 'Strong in Loss']  # Replace with your column names
df_impact_totals23['Games'] = df_impact_totals23[columns_to_sum].sum(axis=1)
df_impact_totals23 = df_impact_totals23[['Year','Games','Goalie Win','Goalie Loss','Strong in Loss','Bad in Win','No Impact']]

# Display the result

# %%
df_combined25 = pd.concat([df_lukasdostal25,df_johngibson25,df_joonaskorpisalo25,df_jeremyswayman25,df_jamesreimer25,
                          df_ukkapekkaluukkonen25,df_devonlevi25,df_danvladar25,df_dustinwolf25,
                          df_frederikandersen25,df_pyotrkochetkov25,df_petrmrazek25,df_laurentbrossoit25,
                          df_alexandargeorgiev25,df_justusannunen25,df_elvismerzlikins25,df_daniiltarasov25,
                          df_jakeoettinger25,df_caseydesmith25,df_camtalbot25,df_alexlyon25,df_villehusso25,
                          df_calvinpicakrd25,df_stuartskinner25,df_spencerknight25,df_sergeibobrovsky25,
                          df_darcykuemper25,df_davidrittich25,df_pheonixcopley25,df_filipgustavsson25,
                          df_marcandrefleury25,df_careyprice25,df_caydenprimeau25,df_sammontembeault25,df_juusesaros25,
                          df_scottwedgewood25,df_jakeallen25,df_jacobmarkstrom25,df_ilyasorokin25,df_semyonvarlamov25,
                          df_igorshesterkin25,df_jonathanquick25,df_linusullmark25,df_antonforsberg25,
                          df_samuelersson25,df_ivanfedotov25,df_tristanjarry25,df_alexnedeljkovic25,
                          df_yaroslavaskarov25,df_mackenzieblackwood25,df_vitekvanecek25,df_joeydaccord25,
                          df_philippgrubauer25,df_jordanbinnington25,df_joelhofer25,df_andreivasilevskiy25,
                          df_jonasjohansson25,df_josephwoll25,df_anthonystolarz25,df_karelvejmelka25,
                          df_connoringram25,df_thatcherdemko23,df_arturssilovs25,df_ilyasamsonov25,df_adinhill25,
                          df_robinlehner25,df_charlielindgren25,df_loganthompson25,df_ericcomrie25,
                          df_connorhellebuyck25,df_kaapokahkonen25], axis=0)

df_impact_totals25 = df_combined25.groupby(['Goalie', 'Team','Impact']).size().unstack(fill_value=0)
df_impact_totals25['Year'] = '2024-25'
columns_to_sum = ['Bad in Win', 'Goalie Loss', 'Goalie Win', 'No Impact', 'Strong in Loss']  # Replace with your column names
df_impact_totals25['Games'] = df_impact_totals25[columns_to_sum].sum(axis=1)
df_impact_totals25 = df_impact_totals25[['Year','Games','Goalie Win','Goalie Loss','Strong in Loss','Bad in Win','No Impact']]

# Display the result

# %%
df_impact = pd.concat ([df_impact_totals,df_impact_totals23,df_impact_totals25], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/29/2lzj4h214tv_0y9lvhfm4f5w0000gn/T/ipykernel_2260/3696989803.py in <module>
# ----> 1 df_impact = pd.concat ([df_impact_totals,df_impact_totals23,df_impact_totals25], axis=0)
#
# NameError: name 'df_impact_totals25' is not defined

# %%
html_table = df_impact.to_html(index=True, classes='table table-striped table-bordered', border=0)

# Add the Bootstrap, DataTables, and dropdown menu for the year filter
bootstrap_html = f"""
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css">

<script src="https://code.jquery.com/jquery-3.5.1.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js"></script>

<!-- Include Popper.js and Bootstrap's JS -->
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>
!-- Navbar (Toolbar) -->
<nav class="navbar navbar-expand-lg navbar-light bg-light fixed-top">
    <a class="navbar-brand" href="index.html">Goalie Wins</a>
    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav">
             <li class="nav-item">
                <a class="nav-link" href="">Daily</a>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="bootstrap_impact_totals.html">Yearly</a>
            </li>
            <!-- Dropdown with hover and click functionality -->
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownHover" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Leaders
                </a>
                <div class="dropdown-menu" aria-labelledby="navbarDropdownHover">
                    <a class="dropdown-item" href="bootstrap_win24_totals.html">2023-24 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss24_totals.html">2023-24 Losses</a>
                    <a class="dropdown-item" href="bootstrap_win23_totals.html">2022-23 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss23_totals.html">2022-23 Losses</a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="#">About</a>
            </li>
        </ul>
    </div>
</nav>



<script>
    $(document).ready(function() {{
        // Initialize DataTables
        $('.table').DataTable();

        // Ensure dropdown toggles on click and hover
        $('.nav-item.dropdown').on('mouseenter', function() {{
            $(this).addClass('show');
            $(this).find('.dropdown-menu').addClass('show');
        }});

        $('.nav-item.dropdown').on('mouseleave', function() {{
            $(this).removeClass('show');
            $(this).find('.dropdown-menu').removeClass('show');
        }});

        $('.nav-item.dropdown').on('click', function(e) {{
            if (!$(this).hasClass('show')) {{
                $(this).addClass('show');
                $(this).find('.dropdown-menu').addClass('show');
            }} else {{
                $(this).removeClass('show');
                $(this).find('.dropdown-menu').removeClass('show');
            }}
            e.stopPropagation();
        }});
    }});
</script>



<!-- Year Dropdown -->
<div class="container mt-3">
    <label for="yearSelect">Select Year:</label>
    <select id="yearSelect" class="form-control" style="width: 200px;">
        <option value="">All</option>
        <option value="2022-23">2022-23</option>
        <option value="2023-24">2023-24</option>
        <option value="2024-25">2024-25</option>
    </select>
</div>
<div class="container mt-3">
    <label for="teamSelect">Select Team:</label>
    <select id="teamSelect" class="form-control" style="width: 200px;">
        <option value="">All</option>
        <option value="ANA">Anaheim</option>
        <option value="BOS">Boston</option>
        <option value="BUF">Buffalo</option>        
        <option value="CGY">Calgary</option>
        <option value="CAR">Carolina</option>
        <option value="CHI">Chicago</option>
        <option value="COL">Colorado</option>
        <option value="CBJ">Columbus</option>
        <option value="DAL">Dallas</option>
        <option value="DET">Detroit</option>
        <option value="EDM">Edmonton</option>
        <option value="FLA">Florida</option>
        <option value="LAK">Los Angeles</option>
        <option value="MIN">Minnesota</option>
        <option value="MTL">Montreal</option>
        <option value="NSH">Nashville</option>
        <option value="NJD">New Jersey</option>
        <option value="NYI">Islanders</option>
        <option value="NYR">Rangers</option>
        <option value="OTT">Ottawa</option>
        <option value="PHI">Philadelphia</option>
        <option value="PIT">Pittsburgh</option>
        <option value="SJS">San Jose</option>
        <option value="SEA">Seattle</option>
        <option value="STL">St. Louis</option>
        <option value="TBL">Tampa Bay</option>
        <option value="TOR">Toronto</option>
        <option value="ARI","UTA">Utah</option>
        <option value="VAN">Vancouver</option>
        <option value="VEG">Vegas</option>
        <option value="WSH">Washington</option>
        <option value="WPG">Winnipeg</option>
        

    </select>
</div>



<!-- Initialize DataTables and reload based on selected year -->

<script>
$(document).ready(function() {{
    var table = $('table').DataTable();

    // Event listener for the year dropdown
    $('#yearSelect').on('change', function() {{
        var selectedYear = $(this).val();

        // Filter the table data based on the selected year
        table.search(selectedYear).draw();
    }});

    // Event listener for the team dropdown
    $('#teamSelect').on('change', function() {{
        var selectedTeam = $(this).val();

        // Filter the table data based on the selected team
        table.column(1).search(selectedTeam).draw();
    }});
}});
</script>
<div class="container">
    <!-- DataTable -->
    {html_table}
</div>


"""

# Save the HTML file with the styled and sortable table and dropdown
with open('bootstrap_impact_totals.html', 'w') as file:
    file.write(bootstrap_html)

# %%
df_impact_totals23['Goalie Wins Rank'] = df_impact_totals23['Goalie Win'].rank(ascending=False, method='min').astype(int)
df_impact_totals23['Goalie Loss Rank'] = df_impact_totals23.loc[df_impact_totals23['Games'] > 25, 'Goalie Loss'].rank(ascending=True, method='min')
df_impact_totals['Goalie Wins Rank'] = df_impact_totals['Goalie Win'].rank(ascending=False, method='min').astype(int)
df_impact_totals['Goalie Loss Rank'] = df_impact_totals.loc[df_impact_totals['Games'] > 25, 'Goalie Loss'].rank(ascending=True, method='min')

# %%
df_sortedw23 = df_impact_totals23.sort_values(by='Goalie Wins Rank')
df_sortedl23 = df_impact_totals23.sort_values(by='Goalie Loss Rank')
df_sortedw24 = df_impact_totals.sort_values(by='Goalie Wins Rank')
df_sortedl24 = df_impact_totals.sort_values(by='Goalie Loss Rank')

# %%
win23_df = df_sortedw23[['Year','Goalie Win']].head(11)
loss23_df = df_sortedl23[['Year','Goalie Loss']].head(11)
win24_df = df_sortedw24[['Year','Goalie Win']].head(11)
loss24_df = df_sortedl24[['Year','Goalie Loss']].head(11)

# %%
filtered_df = df_combined[df_combined['Date'] == '2024-04-18']
filtered_df = filtered_df[['Goalie','Team','Date','Games','xGAE','Result','GD','Impact']]
filtered_df
# Out:
#                Goalie Team        Date        Games  xGAE Result  GD  \
# 43       Lukas Dostal  ANA  2024-04-18   ANA at VGK  2.44      W   3
# 16        Dustin Wolf  CGY  2024-04-18   S.J at CGY  1.00      W   4
# 13     Justus Annunen  COL  2024-04-18   EDM at COL  2.79      W   4
# 31    Arvid Soderblom  CHI  2024-04-18   CHI at L.A -0.99      L  -1
# 58     Stuart Skinner  EDM  2024-04-18   EDM at COL -2.58      L  -4
# 23     Calvin Pickard  EDM  2024-04-18   EDM at COL  0.27      L  -4
# 53         Cam Talbot  LAK  2024-04-18   CHI at L.A -2.65      W   1
# 39  Marc-Andre Fleury  MIN  2024-04-18   SEA at MIN -0.80      L  -1
# 5        Devin Cooley  SJS  2024-04-18   S.J at CGY -3.16      L  -4
# 1      Georgi Romanov  SJS  2024-04-18   S.J at CGY  1.73      L  -4
# 49       Joey Daccord  SEA  2024-04-18   SEA at MIN -1.00      W   1
# 50     Thatcher Demko  VAN  2024-04-18   VAN at WPG -0.50      L  -2
# 34          Adin Hill  VEG  2024-04-18   ANA at VGK -1.72      L  -3
# ...

# %%
html_table = filtered_df.to_html(index=False, classes='table table-striped table-bordered', border=0)
# Add the Bootstrap, DataTables, and dropdown menu for the year filter
bootstrap_html = f"""
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css">

<script src="https://code.jquery.com/jquery-3.5.1.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js"></script>

<!-- Include Popper.js and Bootstrap's JS -->
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>

<!-- Navbar (Toolbar) -->
<nav class="navbar navbar-expand-lg navbar-light bg-light fixed-top">
    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <a class="navbar-brand" href="#">Goalie Wins</a>
    <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav">
             <li class="nav-item">
                <a class="nav-link" href="">Daily</a>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="bootstrap_impact_totals.html">Yearly</a>
            </li>
            <!-- Dropdown with hover and click functionality -->
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownHover" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Leaders
                </a>
                <div class="dropdown-menu" aria-labelledby="navbarDropdownHover">
                    <a class="dropdown-item" href="bootstrap_win24_totals.html">2023-24 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss24_totals.html">2023-24 Losses</a>
                    <a class="dropdown-item" href="bootstrap_win23_totals.html">2022-23 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss23_totals.html">2022-23 Losses</a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="#">About</a>
            </li>
        </ul>
    </div>
</nav>

<script>
    $(document).ready(function() {{
        // Initialize DataTables with 50 rows display
        $('.table').DataTable({{
            pageLength: 50,
            responsive: true
        }});

        // Ensure dropdown toggles on click and hover
        $('.nav-item.dropdown').on('mouseenter', function() {{
            $(this).addClass('show');
            $(this).find('.dropdown-menu').addClass('show');
        }});

        $('.nav-item.dropdown').on('mouseleave', function() {{
            $(this).removeClass('show');
            $(this).find('.dropdown-menu').removeClass('show');
        }});

        $('.nav-item.dropdown').on('click', function(e) {{
            if (!$(this).hasClass('show')) {{
                $(this).addClass('show');
                $(this).find('.dropdown-menu').addClass('show');
            }} else {{
                $(this).removeClass('show');
                $(this).find('.dropdown-menu').removeClass('show');
            }}
            e.stopPropagation();
        }});
    }});
</script>

<div class="container">
    <!-- DataTable -->
    <h2 class="mt-5">April 18</h2> <!-- Table header -->
    {html_table}
</div>
"""

# Save the HTML file with the styled and sortable table and dropdown
with open('index.html', 'w') as file:
    file.write(bootstrap_html)

# %%
html_table = win23_df.to_html(index=True, classes='table table-striped table-bordered', border=0)

# Add the Bootstrap, DataTables, and dropdown menu for the year filter
bootstrap_html = f"""
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css">

<script src="https://code.jquery.com/jquery-3.5.1.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js"></script>

<!-- Include Popper.js and Bootstrap's JS -->
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>

!-- Navbar (Toolbar) -->
<nav class="navbar navbar-expand-lg navbar-light bg-light fixed-top">
    <a class="navbar-brand" href="index.html">Goalie Wins</a>
    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav">
             <li class="nav-item">
                <a class="nav-link" href="">Daily</a>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="bootstrap_impact_totals.html">Yearly</a>
            </li>
            <!-- Dropdown with hover and click functionality -->
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownHover" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Leaders
                </a>
                <div class="dropdown-menu" aria-labelledby="navbarDropdownHover">
                    <a class="dropdown-item" href="bootstrap_win24_totals.html">2023-24 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss24_totals.html">2023-24 Losses</a>
                    <a class="dropdown-item" href="bootstrap_win23_totals.html">2022-23 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss23_totals.html">2022-23 Losses</a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="#">About</a>
            </li>
        </ul>
    </div>
</nav>



<script>
    $(document).ready(function() {{
        // Initialize DataTables
        $('.table').DataTable();

        // Ensure dropdown toggles on click and hover
        $('.nav-item.dropdown').on('mouseenter', function() {{
            $(this).addClass('show');
            $(this).find('.dropdown-menu').addClass('show');
        }});

        $('.nav-item.dropdown').on('mouseleave', function() {{
            $(this).removeClass('show');
            $(this).find('.dropdown-menu').removeClass('show');
        }});

        $('.nav-item.dropdown').on('click', function(e) {{
            if (!$(this).hasClass('show')) {{
                $(this).addClass('show');
                $(this).find('.dropdown-menu').addClass('show');
            }} else {{
                $(this).removeClass('show');
                $(this).find('.dropdown-menu').removeClass('show');
            }}
            e.stopPropagation();
        }});
    }});
</script>


<div class="container">
    <!-- DataTable -->
    {html_table}
</div>
"""

# Save the HTML file with the styled and sortable table and dropdown
with open('bootstrap_win23_totals.html', 'w') as file:
    file.write(bootstrap_html)

# %%
html_table = win24_df.to_html(index=True, classes='table table-striped table-bordered', border=0)

# Add the Bootstrap, DataTables, and dropdown menu for the year filter
bootstrap_html = f"""
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css">

<script src="https://code.jquery.com/jquery-3.5.1.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js"></script>

<!-- Include Popper.js and Bootstrap's JS -->
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>

!-- Navbar (Toolbar) -->
<nav class="navbar navbar-expand-lg navbar-light bg-light fixed-top">
    <a class="navbar-brand" href="index.html">Goalie Wins</a>
    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav">
             <li class="nav-item">
                <a class="nav-link" href="">Daily</a>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="bootstrap_impact_totals.html">Yearly</a>
            </li>
            <!-- Dropdown with hover and click functionality -->
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownHover" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Leaders
                </a>
                <div class="dropdown-menu" aria-labelledby="navbarDropdownHover">
                    <a class="dropdown-item" href="bootstrap_win24_totals.html">2023-24 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss24_totals.html">2023-24 Losses</a>
                    <a class="dropdown-item" href="bootstrap_win23_totals.html">2022-23 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss23_totals.html">2022-23 Losses</a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="#">About</a>
            </li>
        </ul>
    </div>
</nav>



<script>
    $(document).ready(function() {{
        // Initialize DataTables
        $('.table').DataTable();

        // Ensure dropdown toggles on click and hover
        $('.nav-item.dropdown').on('mouseenter', function() {{
            $(this).addClass('show');
            $(this).find('.dropdown-menu').addClass('show');
        }});

        $('.nav-item.dropdown').on('mouseleave', function() {{
            $(this).removeClass('show');
            $(this).find('.dropdown-menu').removeClass('show');
        }});

        $('.nav-item.dropdown').on('click', function(e) {{
            if (!$(this).hasClass('show')) {{
                $(this).addClass('show');
                $(this).find('.dropdown-menu').addClass('show');
            }} else {{
                $(this).removeClass('show');
                $(this).find('.dropdown-menu').removeClass('show');
            }}
            e.stopPropagation();
        }});
    }});
</script>


<div class="container">
    <!-- DataTable -->
    {html_table}
</div>










"""

# Save the HTML file with the styled and sortable table and dropdown
with open('bootstrap_win24_totals.html', 'w') as file:
    file.write(bootstrap_html)

# %%
html_table = loss23_df.to_html(index=True, classes='table table-striped table-bordered', border=0)

# Add the Bootstrap, DataTables, and dropdown menu for the year filter
bootstrap_html = f"""
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css">

<script src="https://code.jquery.com/jquery-3.5.1.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js"></script>

<!-- Include Popper.js and Bootstrap's JS -->
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>

!-- Navbar (Toolbar) -->
<nav class="navbar navbar-expand-lg navbar-light bg-light fixed-top">
    <a class="navbar-brand" href="index.html">Goalie Wins</a>
    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav">
            <li class="nav-item">
                <a class="nav-link" href="">Daily</a>
            </li>
              <li class="nav-item">
                <a class="nav-link" href="bootstrap_impact_totals.html">Yearly</a>
            </li>
            <!-- Dropdown with hover and click functionality -->
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownHover" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Leaders
                </a>
                <div class="dropdown-menu" aria-labelledby="navbarDropdownHover">
                    <a class="dropdown-item" href="bootstrap_win24_totals.html">2023-24 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss24_totals.html">2023-24 Losses</a>
                    <a class="dropdown-item" href="bootstrap_win23_totals.html">2022-23 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss23_totals.html">2022-23 Losses</a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="#">About</a>
            </li>
        </ul>
    </div>
</nav>



<script>
    $(document).ready(function() {{
        // Initialize DataTables
        $('.table').DataTable();

        // Ensure dropdown toggles on click and hover
        $('.nav-item.dropdown').on('mouseenter', function() {{
            $(this).addClass('show');
            $(this).find('.dropdown-menu').addClass('show');
        }});

        $('.nav-item.dropdown').on('mouseleave', function() {{
            $(this).removeClass('show');
            $(this).find('.dropdown-menu').removeClass('show');
        }});

        $('.nav-item.dropdown').on('click', function(e) {{
            if (!$(this).hasClass('show')) {{
                $(this).addClass('show');
                $(this).find('.dropdown-menu').addClass('show');
            }} else {{
                $(this).removeClass('show');
                $(this).find('.dropdown-menu').removeClass('show');
            }}
            e.stopPropagation();
        }});
    }});
</script>


<div class="container">
    <!-- DataTable -->
    {html_table}
</div>






"""

# Save the HTML file with the styled and sortable table and dropdown
with open('bootstrap_loss23_totals.html', 'w') as file:
    file.write(bootstrap_html)

# %%
html_table = loss24_df.to_html(index=True, classes='table table-striped table-bordered', border=0)

# Add the Bootstrap, DataTables, and dropdown menu for the year filter
bootstrap_html = f"""
<meta charset="UTF-8">
<meta name="viewport" content="width=device-width, initial-scale=1">
<link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css">
<link rel="stylesheet" href="https://cdn.datatables.net/1.10.21/css/dataTables.bootstrap4.min.css">

<script src="https://code.jquery.com/jquery-3.5.1.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/jquery.dataTables.min.js"></script>
<script src="https://cdn.datatables.net/1.10.21/js/dataTables.bootstrap4.min.js"></script>

<!-- Include Popper.js and Bootstrap's JS -->
<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.16.0/umd/popper.min.js"></script>
<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/js/bootstrap.min.js"></script>

!-- Navbar (Toolbar) -->
<nav class="navbar navbar-expand-lg navbar-light bg-light fixed-top">
    <a class="navbar-brand" href="index.html">Goalie Wins</a>
    <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
    </button>
    <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav">
             <li class="nav-item">
                <a class="nav-link" href="">Daily</a>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="bootstrap_impact_totals.html">Yearly</a>
            </li>
            <!-- Dropdown with hover and click functionality -->
            <li class="nav-item dropdown">
                <a class="nav-link dropdown-toggle" href="#" id="navbarDropdownHover" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
                    Leaders
                </a>
                <div class="dropdown-menu" aria-labelledby="navbarDropdownHover">
                    <a class="dropdown-item" href="bootstrap_win24_totals.html">2023-24 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss24_totals.html">2023-24 Losses</a>
                    <a class="dropdown-item" href="bootstrap_win23_totals.html">2022-23 Wins</a>
                    <a class="dropdown-item" href="bootstrap_loss23_totals.html">2022-23 Losses</a>
                </div>
            </li>
            <li class="nav-item">
                <a class="nav-link" href="#">About</a>
            </li>
        </ul>
    </div>
</nav>



<script>
    $(document).ready(function() {{
        // Initialize DataTables
        $('.table').DataTable();

        // Ensure dropdown toggles on click and hover
        $('.nav-item.dropdown').on('mouseenter', function() {{
            $(this).addClass('show');
            $(this).find('.dropdown-menu').addClass('show');
        }});

        $('.nav-item.dropdown').on('mouseleave', function() {{
            $(this).removeClass('show');
            $(this).find('.dropdown-menu').removeClass('show');
        }});

        $('.nav-item.dropdown').on('click', function(e) {{
            if (!$(this).hasClass('show')) {{
                $(this).addClass('show');
                $(this).find('.dropdown-menu').addClass('show');
            }} else {{
                $(this).removeClass('show');
                $(this).find('.dropdown-menu').removeClass('show');
            }}
            e.stopPropagation();
        }});
    }});
</script>


<div class="container">
    <!-- DataTable -->
    {html_table}
</div>






"""

# Save the HTML file with the styled and sortable table and dropdown
with open('bootstrap_loss24_totals.html', 'w') as file:
    file.write(bootstrap_html)
